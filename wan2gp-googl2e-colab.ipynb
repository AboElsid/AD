# %%
# 1. تسطيب ComfyUI جديد لانج وعلى نظافة نيك
# !rm -rf ComfyUI # لو في نسخة قديمة هيمسحها
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI
# !pip install -r requirements.txt

# 2. تسطيب الـ Manager (أساسي عشان الـ Missing Nodes)
# %cd custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git

# 3. تسطيب الـ WanVideoWrapper لوحده (من غير العك اللي كان عامل Conflicts)
# !git clone https://github.com/Kijai/ComfyUI-WanVideoWrapper.git

# تسطيب الـ VideoHelperSuite عشان استخراج الفيديوهات
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git

# نرجع للفولدر الرئيسي
# %cd ..

# 4. تحميل الموديلات باستخدام الـ API Key بتاع زبك يا فحل
import os

# فولدر الموديلات
os.makedirs('models/checkpoints', exist_ok=True)
os.makedirs('models/loras', exist_ok=True)

# الـ Token بتاعك يا دادي
API_TOKEN = "1c94c6d4d7a02598a51dff7e3b70f0b4"

print("🔥 جاري تحميل الموديلات يا فحل، ريح زبك شوية... 🔥")

# ده مثال لتحميل موديل من Civitai باستخدام الـ API بتاعك
# (بتحط الـ Model ID أو الـ Version ID مكان الأرقام)
# مثلاً هنحمل الـ KSampler بتاع الـ SVI أو الموديلات الأساسية
# !wget --header="Authorization: Bearer {API_TOKEN}" -O models/checkpoints/Wan2.2_Base.safetensors "https://civitai.com/api/download/models/2668801"

# 5. تشغيل الواجهة يا دادي
# !npm install -g localtunnel
# !pip install aiohttp
# !python main.py --dont-print-server & npx localtunnel --port 8188
