# %% [markdown]
# # Colab for roop-unleashed - Gradio version
# https://github.com/DJHanceNL/Future-Roop

# %% [markdown]
# Install CUDA 12.6 & CUDNN on Google Cloud Compute

# %%
# !apt-get -y update
# !apt-get -y install cuda-toolkit-12-6
# !apt-get -y install cudnn9-cuda-12

import os
os.environ["LD_LIBRARY_PATH"] += ":" + "/usr/local/cuda-12/lib64"
os.environ["LD_LIBRARY_PATH"] += ":" + "/usr/local/cuda-12.6/lib64"

# !nvcc --version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,383 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,913 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,767 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,785 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,302 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,626 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,861 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,107 kB]
# Fetched 39.9 MB in 7s (5,365 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core cuda-cccl-12-6 cuda-command-line-tools-12-6 cuda-compiler-12-6
#   cuda-crt-12-6 cuda-cudart-12-6 cuda-cudart-dev-12-6 cuda-cuobjdump-12-6
#   cuda-cupti-12-6 cuda-cupti-dev-12-6 cuda-cuxxfilt-12-6
#   cuda-documentation-12-6 cuda-driver-dev-12-6 cuda-gdb-12-6
#   cuda-libraries-12-6 cuda-libraries-dev-12-6 cuda-nsight-12-6
#   cuda-nsight-compute-12-6 cuda-nsight-systems-12-6 cuda-nvcc-12-6
#   cuda-nvdisasm-12-6 cuda-nvml-dev-12-6 cuda-nvprof-12-6 cuda-nvprune-12-6
#   cuda-nvrtc-12-6 cuda-nvrtc-dev-12-6 cuda-nvtx-12-6 cuda-nvvm-12-6
#   cuda-nvvp-12-6 cuda-opencl-12-6 cuda-opencl-dev-12-6 cuda-profiler-api-12-6
#   cuda-sanitizer-12-6 cuda-toolkit-12-6-config-common cuda-tools-12-6
#   cuda-visual-tools-12-6 default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra gds-tools-12-6 gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libcublas-12-6 libcublas-dev-12-6 libcufft-12-6
#   libcufft-dev-12-6 libcufile-12-6 libcufile-dev-12-6 libcurand-12-6
#   libcurand-dev-12-6 libcusolver-12-6 libcusolver-dev-12-6 libcusparse-12-6
#   libcusparse-dev-12-6 libnpp-12-6 libnpp-dev-12-6 libnvfatbin-12-6
#   libnvfatbin-dev-12-6 libnvjitlink-12-6 libnvjitlink-dev-12-6 libnvjpeg-12-6
#   libnvjpeg-dev-12-6 libxcb-cursor0 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxcomposite1 libxkbcommon-x11-0 libxtst6
#   libxxf86dga1 nsight-compute-2024.3.2 nsight-systems-2024.5.1 openjdk-11-jre
#   openjdk-11-jre-headless session-migration x11-utils
# Suggested packages:
#   libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core cuda-cccl-12-6 cuda-command-line-tools-12-6 cuda-compiler-12-6
#   cuda-crt-12-6 cuda-cudart-12-6 cuda-cudart-dev-12-6 cuda-cuobjdump-12-6
#   cuda-cupti-12-6 cuda-cupti-dev-12-6 cuda-cuxxfilt-12-6
#   cuda-documentation-12-6 cuda-driver-dev-12-6 cuda-gdb-12-6
#   cuda-libraries-12-6 cuda-libraries-dev-12-6 cuda-nsight-12-6
#   cuda-nsight-compute-12-6 cuda-nsight-systems-12-6 cuda-nvcc-12-6
#   cuda-nvdisasm-12-6 cuda-nvml-dev-12-6 cuda-nvprof-12-6 cuda-nvprune-12-6
#   cuda-nvrtc-12-6 cuda-nvrtc-dev-12-6 cuda-nvtx-12-6 cuda-nvvm-12-6
#   cuda-nvvp-12-6 cuda-opencl-12-6 cuda-opencl-dev-12-6 cuda-profiler-api-12-6
#   cuda-sanitizer-12-6 cuda-toolkit-12-6 cuda-toolkit-12-6-config-common
#   cuda-tools-12-6 cuda-visual-tools-12-6 default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra gds-tools-12-6
#   gsettings-desktop-schemas libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libcublas-12-6 libcublas-dev-12-6 libcufft-12-6 libcufft-dev-12-6
#   libcufile-12-6 libcufile-dev-12-6 libcurand-12-6 libcurand-dev-12-6
#   libcusolver-12-6 libcusolver-dev-12-6 libcusparse-12-6 libcusparse-dev-12-6
#   libnpp-12-6 libnpp-dev-12-6 libnvfatbin-12-6 libnvfatbin-dev-12-6
#   libnvjitlink-12-6 libnvjitlink-dev-12-6 libnvjpeg-12-6 libnvjpeg-dev-12-6
#   libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomposite1 libxkbcommon-x11-0 libxtst6 libxxf86dga1
#   nsight-compute-2024.3.2 nsight-systems-2024.5.1 openjdk-11-jre
#   openjdk-11-jre-headless session-migration x11-utils
# 0 upgraded, 88 newly installed, 0 to remove and 87 not upgraded.
# Need to get 3,020 MB of archives.
# After this operation, 6,764 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-12-6 12.6.77-1 [974 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-12-6 12.6.80-1 [10.2 MB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-12-6 12.6.80-1 [3,927 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-12-6 12.6.77-1 [49.9 MB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.30+7-1ubuntu1~22.04 [42.6 MB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-12-6 12.6.77-1 [221 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-12-6 12.6.77-1 [25.5 MB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-12-6 12.6.80-1 [2,434 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-12-6 12.6.77-1 [51.5 kB]
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-12-6 12.6.77-1 [10.1 MB]
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-12-6 12.6.3-1 [2,550 B]
# Get:17 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-12-6 12.6.77-1 [191 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-6-config-common 12.6.77-1 [16.5 kB]
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-12-6 12.6.77-1 [166 kB]
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-12-6 12.6.77-1 [29.0 kB]
# Get:21 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-12-6 12.6.77-1 [1,026 kB]
# Get:22 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvm-12-6 12.6.85-1 [17.9 MB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.30+7-1ubuntu1~22.04 [214 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:32 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-crt-12-6 12.6.85-1 [77.4 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-12-6 12.6.85-1 [32.6 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-12-6 12.6.77-1 [59.4 kB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-12-6 12.6.3-1 [2,510 B]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-12-6 12.6.77-1 [50.0 kB]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-12-6 12.6.85-1 [17.0 MB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-12-6 12.6.77-1 [24.0 kB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-12-6 12.6.4.1-1 [257 MB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-12-6 11.3.0.4-1 [160 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-12-6 1.11.1.6-1 [847 kB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-12-6 10.3.7.77-1 [41.4 MB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-12-6 11.7.1.2-1 [97.2 MB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-12-6 12.5.4.2-1 [120 MB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-12-6 12.3.1.54-1 [93.8 MB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-12-6 12.6.85-1 [14.7 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-12-6 12.6.77-1 [734 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-12-6 12.3.3.54-1 [2,326 kB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-12-6 12.6.3-1 [2,610 B]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-12-6 12.6.77-1 [18.6 kB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-12-6 12.6.85-1 [17.6 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-dev-12-6 12.6.77-1 [87.7 kB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-12-6 12.6.4.1-1 [277 MB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-12-6 11.3.0.4-1 [321 MB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-12-6 1.11.1.6-1 [2,446 kB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-12-6 10.3.7.77-1 [41.7 MB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-12-6 11.7.1.2-1 [66.7 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-12-6 12.5.4.2-1 [123 MB]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-12-6 12.3.1.54-1 [92.4 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-dev-12-6 12.6.85-1 [14.6 MB]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-dev-12-6 12.6.77-1 [607 kB]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-12-6 12.3.3.54-1 [2,023 kB]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-12-6 12.6.3-1 [2,654 B]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-12-6 12.6.77-1 [119 MB]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2024.3.2 2024.3.2.3-1 [425 MB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-12-6 12.6.3-1 [4,056 B]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2024.5.1 2024.5.1.113-245134619542v0 [356 MB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-12-6 12.6.3-1 [3,348 B]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-12-6 12.6.77-1 [148 kB]
# Get:84 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-12-6 12.6.80-1 [115 MB]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-12-6 12.6.3-1 [2,946 B]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-12-6 1.11.1.6-1 [39.0 MB]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-12-6 12.6.3-1 [2,470 B]
# Get:88 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-6 12.6.3-1 [3,324 B]
# Fetched 3,020 MB in 41s (74.0 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libatspi2.0-0:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../00-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../01-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../02-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../03-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../04-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package cuda-cccl-12-6.
# Preparing to unpack .../05-cuda-cccl-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cccl-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-cupti-12-6.
# Preparing to unpack .../06-cuda-cupti-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-cupti-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-6.
# Preparing to unpack .../07-cuda-cupti-dev-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-6.
# Preparing to unpack .../08-cuda-nvdisasm-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-6.
# Preparing to unpack .../09-cuda-cuobjdump-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-gdb-12-6.
# Preparing to unpack .../10-cuda-gdb-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-gdb-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvprof-12-6.
# Preparing to unpack .../11-cuda-nvprof-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-nvprof-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-nvtx-12-6.
# Preparing to unpack .../12-cuda-nvtx-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvtx-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-sanitizer-12-6.
# Preparing to unpack .../13-cuda-sanitizer-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-6.
# Preparing to unpack .../14-cuda-command-line-tools-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-6.
# Preparing to unpack .../15-cuda-cuxxfilt-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-toolkit-12-6-config-common.
# Preparing to unpack .../16-cuda-toolkit-12-6-config-common_12.6.77-1_all.deb ...
# Unpacking cuda-toolkit-12-6-config-common (12.6.77-1) ...
# Selecting previously unselected package cuda-cudart-12-6.
# Preparing to unpack .../17-cuda-cudart-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cudart-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-driver-dev-12-6.
# Preparing to unpack .../18-cuda-driver-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-6.
# Preparing to unpack .../19-cuda-cudart-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvvm-12-6.
# Preparing to unpack .../20-cuda-nvvm-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvvm-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-crt-12-6.
# Preparing to unpack .../21-cuda-crt-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-crt-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-nvcc-12-6.
# Preparing to unpack .../22-cuda-nvcc-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvcc-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-nvprune-12-6.
# Preparing to unpack .../23-cuda-nvprune-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvprune-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-compiler-12-6.
# Preparing to unpack .../24-cuda-compiler-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-compiler-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-documentation-12-6.
# Preparing to unpack .../25-cuda-documentation-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-documentation-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvrtc-12-6.
# Preparing to unpack .../26-cuda-nvrtc-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-opencl-12-6.
# Preparing to unpack .../27-cuda-opencl-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-opencl-12-6 (12.6.77-1) ...
# Selecting previously unselected package libcublas-12-6.
# Preparing to unpack .../28-libcublas-12-6_12.6.4.1-1_amd64.deb ...
# Unpacking libcublas-12-6 (12.6.4.1-1) ...
# Selecting previously unselected package libcufft-12-6.
# Preparing to unpack .../29-libcufft-12-6_11.3.0.4-1_amd64.deb ...
# Unpacking libcufft-12-6 (11.3.0.4-1) ...
# Selecting previously unselected package libcufile-12-6.
# Preparing to unpack .../30-libcufile-12-6_1.11.1.6-1_amd64.deb ...
# Unpacking libcufile-12-6 (1.11.1.6-1) ...
# Selecting previously unselected package libcurand-12-6.
# Preparing to unpack .../31-libcurand-12-6_10.3.7.77-1_amd64.deb ...
# Unpacking libcurand-12-6 (10.3.7.77-1) ...
# Selecting previously unselected package libcusolver-12-6.
# Preparing to unpack .../32-libcusolver-12-6_11.7.1.2-1_amd64.deb ...
# Unpacking libcusolver-12-6 (11.7.1.2-1) ...
# Selecting previously unselected package libcusparse-12-6.
# Preparing to unpack .../33-libcusparse-12-6_12.5.4.2-1_amd64.deb ...
# Unpacking libcusparse-12-6 (12.5.4.2-1) ...
# Selecting previously unselected package libnpp-12-6.
# Preparing to unpack .../34-libnpp-12-6_12.3.1.54-1_amd64.deb ...
# Unpacking libnpp-12-6 (12.3.1.54-1) ...
# Selecting previously unselected package libnvjitlink-12-6.
# Preparing to unpack .../35-libnvjitlink-12-6_12.6.85-1_amd64.deb ...
# Unpacking libnvjitlink-12-6 (12.6.85-1) ...
# Selecting previously unselected package libnvfatbin-12-6.
# Preparing to unpack .../36-libnvfatbin-12-6_12.6.77-1_amd64.deb ...
# Unpacking libnvfatbin-12-6 (12.6.77-1) ...
# Selecting previously unselected package libnvjpeg-12-6.
# Preparing to unpack .../37-libnvjpeg-12-6_12.3.3.54-1_amd64.deb ...
# Unpacking libnvjpeg-12-6 (12.3.3.54-1) ...
# Selecting previously unselected package cuda-libraries-12-6.
# Preparing to unpack .../38-cuda-libraries-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-libraries-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-profiler-api-12-6.
# Preparing to unpack .../39-cuda-profiler-api-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-6.
# Preparing to unpack .../40-cuda-nvrtc-dev-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-6.
# Preparing to unpack .../41-cuda-opencl-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package libcublas-dev-12-6.
# Preparing to unpack .../42-libcublas-dev-12-6_12.6.4.1-1_amd64.deb ...
# Unpacking libcublas-dev-12-6 (12.6.4.1-1) ...
# Selecting previously unselected package libcufft-dev-12-6.
# Preparing to unpack .../43-libcufft-dev-12-6_11.3.0.4-1_amd64.deb ...
# Unpacking libcufft-dev-12-6 (11.3.0.4-1) ...
# Selecting previously unselected package libcufile-dev-12-6.
# Preparing to unpack .../44-libcufile-dev-12-6_1.11.1.6-1_amd64.deb ...
# Unpacking libcufile-dev-12-6 (1.11.1.6-1) ...
# Selecting previously unselected package libcurand-dev-12-6.
# Preparing to unpack .../45-libcurand-dev-12-6_10.3.7.77-1_amd64.deb ...
# Unpacking libcurand-dev-12-6 (10.3.7.77-1) ...
# Selecting previously unselected package libcusolver-dev-12-6.
# Preparing to unpack .../46-libcusolver-dev-12-6_11.7.1.2-1_amd64.deb ...
# Unpacking libcusolver-dev-12-6 (11.7.1.2-1) ...
# Selecting previously unselected package libcusparse-dev-12-6.
# Preparing to unpack .../47-libcusparse-dev-12-6_12.5.4.2-1_amd64.deb ...
# Unpacking libcusparse-dev-12-6 (12.5.4.2-1) ...
# Selecting previously unselected package libnpp-dev-12-6.
# Preparing to unpack .../48-libnpp-dev-12-6_12.3.1.54-1_amd64.deb ...
# Unpacking libnpp-dev-12-6 (12.3.1.54-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-6.
# Preparing to unpack .../49-libnvjitlink-dev-12-6_12.6.85-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-6 (12.6.85-1) ...
# Selecting previously unselected package libnvfatbin-dev-12-6.
# Preparing to unpack .../50-libnvfatbin-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking libnvfatbin-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-6.
# Preparing to unpack .../51-libnvjpeg-dev-12-6_12.3.3.54-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-6 (12.3.3.54-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-6.
# Preparing to unpack .../52-cuda-libraries-dev-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-6 (12.6.3-1) ...
# Selecting previously unselected package openjdk-11-jre-headless:amd64.
# Preparing to unpack .../53-openjdk-11-jre-headless_11.0.30+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../54-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../55-openjdk-11-jre_11.0.30+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../56-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-12-6.
# Preparing to unpack .../57-cuda-nsight-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nsight-12-6 (12.6.77-1) ...
# Selecting previously unselected package nsight-compute-2024.3.2.
# Preparing to unpack .../58-nsight-compute-2024.3.2_2024.3.2.3-1_amd64.deb ...
# Unpacking nsight-compute-2024.3.2 (2024.3.2.3-1) ...
# Selecting previously unselected package cuda-nsight-compute-12-6.
# Preparing to unpack .../59-cuda-nsight-compute-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-nsight-compute-12-6 (12.6.3-1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../60-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../61-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../62-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../63-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../64-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../65-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../66-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../67-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../68-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-cursor0:amd64.
# Preparing to unpack .../69-libxcb-cursor0_0.1.1-4ubuntu1_amd64.deb ...
# Unpacking libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../70-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package nsight-systems-2024.5.1.
# Preparing to unpack .../71-nsight-systems-2024.5.1_2024.5.1.113-245134619542v0_amd64.deb ...
# Unpacking nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# Selecting previously unselected package cuda-nsight-systems-12-6.
# Preparing to unpack .../72-cuda-nsight-systems-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-nsight-systems-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-6.
# Preparing to unpack .../73-cuda-nvml-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvvp-12-6.
# Preparing to unpack .../74-cuda-nvvp-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-nvvp-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-visual-tools-12-6.
# Preparing to unpack .../75-cuda-visual-tools-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-6 (12.6.3-1) ...
# Selecting previously unselected package gds-tools-12-6.
# Preparing to unpack .../76-gds-tools-12-6_1.11.1.6-1_amd64.deb ...
# Unpacking gds-tools-12-6 (1.11.1.6-1) ...
# Selecting previously unselected package cuda-tools-12-6.
# Preparing to unpack .../77-cuda-tools-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-tools-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-toolkit-12-6.
# Preparing to unpack .../78-cuda-toolkit-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-toolkit-12-6 (12.6.3-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../79-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../80-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../81-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../82-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../83-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../84-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../85-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../86-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../87-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-cccl-12-6 (12.6.77-1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up gds-tools-12-6 (1.11.1.6-1) ...
# Setting up cuda-documentation-12-6 (12.6.77-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvml-dev-12-6 (12.6.77-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-profiler-api-12-6 (12.6.77-1) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/rmid to provide /usr/bin/rmid (rmid) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/pack200 to provide /usr/bin/pack200 (pack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/unpack200 to provide /usr/bin/unpack200 (unpack200) in auto mode
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up nsight-compute-2024.3.2 (2024.3.2.3-1) ...
# Setting up openjdk-11-jre:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Setting up cuda-nvvm-12-6 (12.6.85-1) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up cuda-nvtx-12-6 (12.6.77-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up cuda-cuxxfilt-12-6 (12.6.77-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvdisasm-12-6 (12.6.77-1) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up cuda-nvprune-12-6 (12.6.77-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up cuda-driver-dev-12-6 (12.6.77-1) ...
# Setting up cuda-nsight-compute-12-6 (12.6.3-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up cuda-toolkit-12-6-config-common (12.6.77-1) ...
# Setting alternatives
# Setting up cuda-cuobjdump-12-6 (12.6.77-1) ...
# Setting up cuda-nvrtc-12-6 (12.6.85-1) ...
# Setting up cuda-sanitizer-12-6 (12.6.77-1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up cuda-cupti-12-6 (12.6.80-1) ...
# Setting up cuda-nvprof-12-6 (12.6.80-1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libcusolver-12-6 (11.7.1.2-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libnvjitlink-12-6 (12.6.85-1) ...
# Setting up libcurand-12-6 (10.3.7.77-1) ...
# Setting up libcufft-12-6 (11.3.0.4-1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libcufft-dev-12-6 (11.3.0.4-1) ...
# Setting up libnpp-12-6 (12.3.1.54-1) ...
# Setting up nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libnvjitlink-dev-12-6 (12.6.85-1) ...
# Setting up libcusparse-12-6 (12.5.4.2-1) ...
# Setting up cuda-cupti-dev-12-6 (12.6.80-1) ...
# Setting up libnvfatbin-12-6 (12.6.77-1) ...
# Setting up libcurand-dev-12-6 (10.3.7.77-1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-nvvp-12-6 (12.6.80-1) ...
# Setting up libnpp-dev-12-6 (12.3.1.54-1) ...
# Setting up libcublas-12-6 (12.6.4.1-1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libcublas-dev-12-6 (12.6.4.1-1) ...
# Setting up cuda-cudart-12-6 (12.6.77-1) ...
# Setting up cuda-gdb-12-6 (12.6.77-1) ...
# Setting up libnvjpeg-12-6 (12.3.3.54-1) ...
# Setting up libcufile-12-6 (1.11.1.6-1) ...
# Setting alternatives
# Setting up cuda-opencl-12-6 (12.6.77-1) ...
# Setting up libcusparse-dev-12-6 (12.5.4.2-1) ...
# Setting up cuda-libraries-12-6 (12.6.3-1) ...
# Setting up cuda-nvrtc-dev-12-6 (12.6.85-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up cuda-nsight-systems-12-6 (12.6.3-1) ...
# Setting up cuda-nsight-12-6 (12.6.77-1) ...
# Setting up libcusolver-dev-12-6 (11.7.1.2-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up cuda-command-line-tools-12-6 (12.6.3-1) ...
# Setting up cuda-opencl-dev-12-6 (12.6.77-1) ...
# Setting up libnvfatbin-dev-12-6 (12.6.77-1) ...
# Setting up libnvjpeg-dev-12-6 (12.3.3.54-1) ...
# Setting up libcufile-dev-12-6 (1.11.1.6-1) ...
# Setting up cuda-cudart-dev-12-6 (12.6.77-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-libraries-dev-12-6 (12.6.3-1) ...
# Setting up cuda-crt-12-6 (12.6.85-1) ...
# Setting up cuda-visual-tools-12-6 (12.6.3-1) ...
# Setting up cuda-nvcc-12-6 (12.6.85-1) ...
# Setting up cuda-tools-12-6 (12.6.3-1) ...
# Setting up cuda-compiler-12-6 (12.6.3-1) ...
# Setting up cuda-toolkit-12-6 (12.6.3-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Some packages could not be installed. This may mean that you have
# requested an impossible situation or if you are using the unstable
# distribution that some required packages have not yet been created
# or been moved out of Incoming.
# The following information may help to resolve the situation:
#
# The following packages have unmet dependencies:
#  libcudnn9-dev-cuda-12 : Depends: libcudnn9-cuda-12 (= 9.19.1.2-1) but 9.8.0.87-1 is to be installed
# E: Unable to correct problems, you have held broken packages.
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %% [markdown]
# Installing & preparing requirements

# %%
# !git clone https://github.com/DJHanceNL/Future-Roop.git
# %cd Future-Roop
# !mv config_colab.yaml config.yaml
# !pip install -r requirements.txt
# Out:
# Cloning into 'Future-Roop'...
# remote: Enumerating objects: 197, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 197 (delta 18), reused 13 (delta 12), pack-reused 168 (from 1)
# Receiving objects: 100% (197/197), 4.74 MiB | 11.49 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/Future-Roop
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu126
# Ignoring torch: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring torchvision: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring onnxruntime: markers 'sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring onnxruntime-silicon: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# Collecting numpy==1.26.4 (from -r requirements.txt (line 2))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting gradio==5.38.0 (from -r requirements.txt (line 3))
#   Downloading gradio-5.38.0-py3-none-any.whl.metadata (16 kB)
# Collecting opencv-python-headless==4.10.0.84 (from -r requirements.txt (line 4))
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting onnx==1.18.0 (from -r requirements.txt (line 5))
#   Downloading onnx-1.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting insightface==0.7.3 (from -r requirements.txt (line 6))
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 18.6 MB/s eta 0:00:00

# %% [markdown]
# Running Future-Roop with default config

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA device is available: {torch.cuda.is_available()}")

# !python run.py

# %% [markdown]
# ### Download generated images folder
# (only needed if you want to zip the generated output)

# %%
import shutil
import os
from google.colab import files

def zip_directory(directory_path, zip_path):
    shutil.make_archive(zip_path, 'zip', directory_path)

# Set the directory path you want to download
directory_path = '/content/roop-unleashed/output'

# Set the zip file name
zip_filename = 'fake_output.zip'

# Zip the directory
zip_directory(directory_path, zip_filename)

# Download the zip file
files.download(zip_filename+'.zip')
